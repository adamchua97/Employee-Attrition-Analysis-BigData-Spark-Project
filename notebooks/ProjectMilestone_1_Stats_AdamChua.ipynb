# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load data and display details

# %%
df = pd.read_csv('employee_attrition_dataset.csv')

# %%
df.head()
# Out:
#    Employee_ID  Age  Gender Marital_Status Department   Job_Role  Job_Level  \
# 0            1   58    Male         Single    Finance    Manager          5
# 1            2   48  Female       Divorced         HR  Assistant          4
# 2            3   34  Female        Married  Marketing    Manager          4
# 3            4   27  Female       Divorced         HR    Manager          4
# 4            5   40    Male        Married         HR    Analyst          1
#
#    Monthly_Income  Hourly_Rate  Years_at_Company  ...  Overtime  \
# 0            7332           81                24  ...        No
# 1            6069           55                18  ...       Yes
# 2           11485           65                 6  ...       Yes
# 3           18707           28                12  ...        No
# 4           16398           92                 3  ...        No
#
#    Project_Count  Average_Hours_Worked_Per_Week  Absenteeism  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Gender                         10000 non-null  object
#  3   Marital_Status                 10000 non-null  object
#  4   Department                     10000 non-null  object
#  5   Job_Role                       10000 non-null  object
#  6   Job_Level                      10000 non-null  int64
#  7   Monthly_Income                 10000 non-null  int64
#  8   Hourly_Rate                    10000 non-null  int64
#  9   Years_at_Company               10000 non-null  int64
#  10  Years_in_Current_Role          10000 non-null  int64
#  11  Years_Since_Last_Promotion     10000 non-null  int64
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#        Employee_ID           Age     Job_Level  Monthly_Income   Hourly_Rate  \
# count  10000.00000  10000.000000  10000.000000    10000.000000  10000.000000
# mean    5000.50000     39.561800      2.990800    11436.716700     57.032300
# std     2886.89568     11.454986      1.410643     4926.528302     24.703261
# min        1.00000     20.000000      1.000000     3000.000000     15.000000
# 25%     2500.75000     30.000000      2.000000     7182.500000     36.000000
# 50%     5000.50000     40.000000      3.000000    11401.500000     57.000000
# 75%     7500.25000     49.000000      4.000000    15679.500000     78.000000
# max    10000.00000     59.000000      5.000000    19999.000000     99.000000
#
#        Years_at_Company  Years_in_Current_Role  Years_Since_Last_Promotion  \
# count      10000.000000           10000.000000                10000.000000
# mean          14.936200               7.451300                    4.471900
# ...

# %%
# tranpsose
df.describe().transpose()
# Out:
#                                  count        mean          std     min  \
# Employee_ID                    10000.0   5000.5000  2886.895680     1.0
# Age                            10000.0     39.5618    11.454986    20.0
# Job_Level                      10000.0      2.9908     1.410643     1.0
# Monthly_Income                 10000.0  11436.7167  4926.528302  3000.0
# Hourly_Rate                    10000.0     57.0323    24.703261    15.0
# Years_at_Company               10000.0     14.9362     8.431657     1.0
# Years_in_Current_Role          10000.0      7.4513     4.042903     1.0
# Years_Since_Last_Promotion     10000.0      4.4719     2.891617     0.0
# Work_Life_Balance              10000.0      2.5024     1.112348     1.0
# Job_Satisfaction               10000.0      3.0380     1.414764     1.0
# Performance_Rating             10000.0      2.5077     1.120833     1.0
# Training_Hours_Last_Year       10000.0     49.5889    28.801393     0.0
# ...

# %% [markdown]
# # Histograms

# %% [markdown]
# ### Create separate df for numerical and categorical variables

# %%
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
numerical_cols
# Out:
# ['Employee_ID',
#  'Age',
#  'Job_Level',
#  'Monthly_Income',
#  'Hourly_Rate',
#  'Years_at_Company',
#  'Years_in_Current_Role',
#  'Years_Since_Last_Promotion',
#  'Work_Life_Balance',
#  'Job_Satisfaction',
#  'Performance_Rating',
#  'Training_Hours_Last_Year',
#  'Project_Count',
#  'Average_Hours_Worked_Per_Week',
#  'Absenteeism',
#  'Work_Environment_Satisfaction',
#  'Relationship_with_Manager',
#  'Job_Involvement',
#  'Distance_From_Home',
#  'Number_of_Companies_Worked']

# %%
categorical_cols
# Out:
# ['Gender', 'Marital_Status', 'Department', 'Job_Role', 'Overtime', 'Attrition']

# %%
# separate dataframes

numerical_df = df[numerical_cols]
categorical_df = df[categorical_cols]

# %%
numerical_df.head()
# Out:
#    Employee_ID  Age  Job_Level  Monthly_Income  Hourly_Rate  Years_at_Company  \
# 0            1   58          5            7332           81                24
# 1            2   48          4            6069           55                18
# 2            3   34          4           11485           65                 6
# 3            4   27          4           18707           28                12
# 4            5   40          1           16398           92                 3
#
#    Years_in_Current_Role  Years_Since_Last_Promotion  Work_Life_Balance  \
# 0                     12                           3                  1
# 1                      7                           5                  1
# 2                      4                           3                  4
# 3                      9                           1                  1
# 4                      9                           1                  3
#
# ...

# %%
categorical_df.head()
# Out:
#    Gender Marital_Status Department   Job_Role Overtime Attrition
# 0    Male         Single    Finance    Manager       No        No
# 1  Female       Divorced         HR  Assistant      Yes        No
# 2  Female        Married  Marketing    Manager      Yes       Yes
# 3  Female       Divorced         HR    Manager       No        No
# 4    Male        Married         HR    Analyst       No        No

# %% [markdown]
# ## Numerical Variables

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Job_Level                      10000 non-null  int64
#  3   Monthly_Income                 10000 non-null  int64
#  4   Hourly_Rate                    10000 non-null  int64
#  5   Years_at_Company               10000 non-null  int64
#  6   Years_in_Current_Role          10000 non-null  int64
#  7   Years_Since_Last_Promotion     10000 non-null  int64
#  8   Work_Life_Balance              10000 non-null  int64
#  9   Job_Satisfaction               10000 non-null  int64
#  10  Performance_Rating             10000 non-null  int64
#  11  Training_Hours_Last_Year       10000 non-null  int64
# ...

# %%
# Create a figure and a grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms on each subplot
sns.histplot(numerical_df, x='Age', ax=axes[0, 0])
axes[0, 0].set_title('Age')

sns.histplot(numerical_df, x='Job_Level', ax=axes[0, 1])
axes[0, 1].set_title('Job Level')

sns.histplot(numerical_df, x='Monthly_Income', ax=axes[1, 0])
axes[1, 0].set_title('Monthly Income')

sns.histplot(numerical_df, x='Hourly_Rate', ax=axes[1, 1])
axes[1, 1].set_title('Hourly Rate')

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
# Create a figure and a grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms on each subplot
sns.histplot(numerical_df, x='Years_at_Company', color='orange', ax=axes[0, 0])
axes[0, 0].set_title('Years at Company')

sns.histplot(numerical_df, x='Years_in_Current_Role', color='orange', ax=axes[0, 1])
axes[0, 1].set_title('Years in Current Role')

sns.histplot(numerical_df, x='Years_Since_Last_Promotion', color='orange', ax=axes[1, 0])
axes[1, 0].set_title('Years Since Last Promotion')

sns.histplot(numerical_df, x='Work_Life_Balance', color='orange', ax=axes[1, 1])
axes[1, 1].set_title('Work Life Balance')

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
# Create a figure and a grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms on each subplot
sns.histplot(numerical_df, x='Job_Satisfaction', color='green', ax=axes[0, 0])
axes[0, 0].set_title('Job Satisfaction')

sns.histplot(numerical_df, x='Performance_Rating', color='green', ax=axes[0, 1])
axes[0, 1].set_title('Performance Rating')

sns.histplot(numerical_df, x='Training_Hours_Last_Year', color='green', ax=axes[1, 0])
axes[1, 0].set_title('Training Hours Last Year')

sns.histplot(numerical_df, x='Project_Count', color='green', ax=axes[1, 1])
axes[1, 1].set_title('Project Count')

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
# Create a figure and a grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms on each subplot
sns.histplot(numerical_df, x='Average_Hours_Worked_Per_Week', color='red', ax=axes[0, 0])
axes[0, 0].set_title('Average Hours Worked Per Week')

sns.histplot(numerical_df, x='Absenteeism', color='red', ax=axes[0, 1])
axes[0, 1].set_title('Absenteeism')

sns.histplot(numerical_df, x='Work_Environment_Satisfaction', color='red', ax=axes[1, 0])
axes[1, 0].set_title('Work Environment Satisfaction')

sns.histplot(numerical_df, x='Relationship_with_Manager', color='red', ax=axes[1, 1])
axes[1, 1].set_title('Relationship with Manager')

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
# Create a figure and a grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms on each subplot
sns.histplot(numerical_df, x='Job_Involvement', color='yellow', ax=axes[0, 0])
axes[0, 0].set_title('Job Involvement')

sns.histplot(numerical_df, x='Distance_From_Home', color='yellow', ax=axes[0, 1])
axes[0, 1].set_title('Distance From Home')

sns.histplot(numerical_df, x='Number_of_Companies_Worked', color='yellow', ax=axes[1, 0])
axes[1, 0].set_title('Number of Companies Worked Previously')

# Adjust the layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical Variables

# %%
categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          10000 non-null  object
#  1   Marital_Status  10000 non-null  object
#  2   Department      10000 non-null  object
#  3   Job_Role        10000 non-null  object
#  4   Overtime        10000 non-null  object
#  5   Attrition       10000 non-null  object
# dtypes: object(6)
# memory usage: 468.9+ KB

# %%
# Categorical variable counts

for col in categorical_cols:
    print(categorical_df[col].value_counts(), "\n")
# Out:
# Gender
# Female    5042
# Male      4958
# Name: count, dtype: int64
#
# Marital_Status
# Married     3375
# Divorced    3330
# Single      3295
# Name: count, dtype: int64
#
# Department
# Marketing    2133
# Sales        2008
# Finance      1990
# HR           1953
# IT           1916
# Name: count, dtype: int64
#
# Job_Role
# Analyst      2572
# Assistant    2538
# Executive    2476
# Manager      2414
# Name: count, dtype: int64
#
# Overtime
# No     5103
# Yes    4897
# Name: count, dtype: int64
#
# Attrition
# No     8003
# Yes    1997
# Name: count, dtype: int64

# %%
# Create a figure and a grid of subplots
fig, axes = plt.subplots(3, 2, figsize=(12, 14))

# Plot histograms on each subplot
sns.barplot(data=categorical_df['Gender'].value_counts(), ax=axes[0, 0], width=0.5)
axes[0, 0].set_title('Gender Frequency Bar Chart')

sns.barplot(data=categorical_df['Marital_Status'].value_counts(), ax=axes[0, 1], width=0.5)
axes[0, 1].set_title('Marital Status Frequency Bar Chart')

sns.barplot(data=categorical_df['Department'].value_counts(), color='orange', ax=axes[1, 0], width=0.5)
axes[1, 0].set_title('Department Frequency Bar Chart')

sns.barplot(data=categorical_df['Job_Role'].value_counts(), color='orange', ax=axes[1, 1], width=0.5)
axes[1, 1].set_title('Job Role Frequency Bar Chart')

sns.barplot(data=categorical_df['Overtime'].value_counts(), color='green', ax=axes[2, 0], width=0.5)
axes[2, 0].set_title('Overtime Frequency Bar Chart')

sns.barplot(data=categorical_df['Attrition'].value_counts(), color='green', ax=axes[2, 1], width=0.5)
axes[2, 1].set_title('Attrition Frequency Bar Chart')

# Adjust the layout
plt.tight_layout()
plt.show()
